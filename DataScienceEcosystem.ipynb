# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This notebook will give an overview of data science tools and ecosystem.

# %% [markdown]
# **Objectives:**
# - list popular languages for data scientists
# - list popular libraries for data scientists
# - list popular tools for data scientists
# - show the usefulness of Python for arithmetic expressions

# %% [markdown]
# Here are some of the most popular languages used by data scientists:
# 1. R
# 2. Python
# 3. Julia

# %% [markdown]
# Data scientists commonly use these libraries, among others:
# 1. Pandas
# 2. TensorFlow
# 3. PyTorch

# %% [markdown]
# | Data Science Tools |
# | ------------------ |
# | RStudio |
# | Jupyter |
# | Apache Zeppelin |

# %% [markdown]
# ### Here are some examples of how Python can evaluate arithmetic expressions

# %%
# This expression uses both multiplication and addition of integers.

(3*4)+5
# Out:
# 17

# %%
# We can convert 200 minutes to hours by dividing it by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# William Haugh
